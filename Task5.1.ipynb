# %% [markdown]
# # Name:- Sonali Ganesh Magar
# # Class:- IF5K
# # Task:- HomeWork5

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
years = ['2001', '2003', '2005', '2007', '2009']
sachin = [1200, 1100, 1000, 900, 850]
kohli  = [1000, 700, 850, 600, 1000]    
sehwag = [850, 950, 1050, 1000, 900]

# %%
x=np.arange(len(years))
width=0.25
plt.bar(x - width,sachin,width=width,label="Sachin")
plt.bar(x ,sehwag,width=width,label="Sehwag")
plt.bar(x + width, kohli,width=width,label="kohli")
plt.xlabel("year")
plt.ylabel("Runs")
plt.title("Run Comparison")
plt.xticks(x,years)
plt.legend()
plt.tight_layout()

# %%
np.arange(len(years))
width=0.25
plt.bar(x - width,sachin,width=width,label="Sachin")
plt.bar(x ,sehwag,width=width,label="Sehwag")
plt.bar(x + width, kohli,width=width,label="kohli")
plt.xlabel("year")
plt.ylabel("Runs")
plt.title("Run Comparison")
plt.xticks(x,years)
plt.legend(loc='upper left')
plt.tight_layout()

# %%
x=np.arange(len(years))
width=0.25
plt.bar(x - width,sachin,width=width,label="Sachin")
plt.bar(x ,sehwag,width=width,label="Sehwag")
plt.bar(x + width, kohli,width=width,label="kohli")
plt.xlabel("year")
plt.ylabel("Runs")
plt.title("Run Comparison")
plt.xticks(x,years)
plt.legend(loc='lower right')
plt.tight_layout()

# %%
x=np.arange(len(years))
width=0.25
plt.bar(x - width,sachin,width=width,label="Sachin")
plt.bar(x ,sehwag,width=width,label="Sehwag")
plt.bar(x + width, kohli,width=width,label="kohli")
plt.xlabel("year")
plt.ylabel("Runs")
plt.title("Run Comparison")
plt.xticks(x,years)
plt.legend(loc='lower left')
plt.tight_layout()

# %%
x=np.arange(len(years))
width=0.25
plt.bar(x - width,sachin,width=width,label="Sachin")
plt.bar(x ,sehwag,width=width,label="Sehwag")
plt.bar(x + width, kohli,width=width,label="kohli")
plt.xlabel("year")
plt.ylabel("Runs")
plt.title("Run Comparison")
plt.xticks(x,years)
plt.legend(loc='center')
plt.tight_layout()

# %%
x=np.arange(len(years))
width=0.25
plt.bar(x - width,sachin,width=width,label="Sachin")
plt.bar(x ,sehwag,width=width,label="Sehwag")
plt.bar(x + width, kohli,width=width,label="kohli")
plt.xlabel("year")
plt.ylabel("Runs")
plt.title("Run Comparison")
plt.xticks(x,years)
plt.legend(loc='center left')
plt.tight_layout()

# %%
total_sachin = sum(sachin)
total_kohli = sum(kohli)
total_sehwag = sum(sehwag)
players = ['Sachin', 'Kohli', 'Sehwag']
totals = [total_sachin, total_kohli, total_sehwag]
plt.figure(figsize=(8,5))
plt.barh(players, totals,0.4,color='pink')
plt.xlabel('Total Runs')
plt.title('Total Runs in Debut 5 Years')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\RUPESH\AppData\Local\Temp\ipykernel_18856\1621955116.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
